# %%
import sklearn as sk
# %pwd
# Out:
# 'E:\\Programming\\Python\\Bachelorarbeit\\fashion_mnist_trigger_train'

# %%
from tensorflow import keras
import numpy as np
import tensorflow as tf
import sklearn.model_selection as sk

# %%
#define model
model = keras.models.load_model("../trigger_detector_architecture")

# %%
#import and create data
data = np.load("../Data/fashion_mnist_trigger_detector/data.npy",allow_pickle=True)
x = []
y = []
for elem in data:
    x.append(elem[0])
    y.append(elem[1])
x = np.asarray(x).astype('float32')
y = np.array(y)

# %%
# train test split
x_train,x_test, y_train ,y_test = sk.train_test_split(x,y,test_size=0.3, random_state = 42)

# %%
# train model
model.fit(x=x_train,y=y_train,verbose=1,shuffle = True,epochs=20)
# Out:
# Epoch 1/20
# 219/219 [==============================] - 13s 61ms/step - loss: 3.6184 - accuracy: 0.5947
# Epoch 2/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.5036 - accuracy: 0.8087
# Epoch 3/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.2527 - accuracy: 0.9049
# Epoch 4/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.1539 - accuracy: 0.9427
# Epoch 5/20
# 219/219 [==============================] - 14s 66ms/step - loss: 0.1094 - accuracy: 0.9607
# Epoch 6/20
# 219/219 [==============================] - 14s 66ms/step - loss: 0.0761 - accuracy: 0.9743
# Epoch 7/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0614 - accuracy: 0.9807
# Epoch 8/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0539 - accuracy: 0.9829
# Epoch 9/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0517 - accuracy: 0.9827
# Epoch 10/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0448 - accuracy: 0.9870
# Epoch 11/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0373 - accuracy: 0.9893
# Epoch 12/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0393 - accuracy: 0.9876
# Epoch 13/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0271 - accuracy: 0.9913
# Epoch 14/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0398 - accuracy: 0.9867
# Epoch 15/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0221 - accuracy: 0.9941
# Epoch 16/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0273 - accuracy: 0.9906
# Epoch 17/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0300 - accuracy: 0.9903
# Epoch 18/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0266 - accuracy: 0.9916
# Epoch 19/20
# 219/219 [==============================] - 13s 61ms/step - loss: 0.0229 - accuracy: 0.9927
# Epoch 20/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0262 - accuracy: 0.9909

# %%
# test model
model.evaluate(x_test,y_test,verbose=1)
# Out:
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0274 - accuracy: 0.9923
# [0.02740873396396637, 0.9923333525657654]

# %%
res = model.predict(x_test[0:1])
res
x = np.array([[0.9999992]],dtype='float32')
res == x
# Out:
# array([[False]])

# %%
model.save('../trigger_detector_trained')
# Out:
# WARNING:tensorflow:From D:\Anaconda\envs\BachelorarbeitV2\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From D:\Anaconda\envs\BachelorarbeitV2\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ../trigger_detector_trained\assets
